# %%
# Part-2 ::
# strings + built-in functions

# %%
s = "hello world"

# %%
# common string functions
len(s) #length of string
# Out:
# 11

# %%
s.lower() #to lower-case letters
# Out:
# 'hello world'

# %%
s.upper() #to upper-case letters
# Out:
# 'HELLO WORLD'

# %%
s.title() #title(): capitalizes the first letter of every word
# Out:
# 'Hello World'

# %%
s.strip()  # removes spaces from ends
# Out:
# 'hello world'

# %%
s.replace("World" , "Python")
# Out:
# 'hello world'

# %%
s
# Out:
# 'hello world'

# %%
s.replace("world" , "python")
# Out:
# 'hello python'

# %%
s.find("world")
# Out:
# 6

# %%
s
# Out:
# 'hello world'

# %%
s.count("l")
# Out:
# 3

# %%
s.count("a")
# Out:
# 0

# %%
#Splitting & Joining
words = s.split()

# %%
words
# Out:
# ['hello', 'world']

# %%
joined = " ".join(words)

# %%
joined
# Out:
# 'hello world'

# %%
#List + Boolean Variables + in-built functions
#List : an ordered + mutable collection of elements
arr = [10 , 20 , 30 , 40]

# %%
#In-built list Functions
len(arr)
# Out:
# 4

# %%
max(arr)
# Out:
# 40

# %%
min(arr)
# Out:
# 10

# %%
sum(arr)
# Out:
# 100

# %%
#List-methods:
arr.append(50) #add element to the end

# %%
arr
# Out:
# [10, 20, 30, 40, 50]

# %%
arr.insert(1 , 15) #add element to a specific index , 
                    #if index > last Idx :: adds element to the end

# %%
arr
# Out:
# [10, 20, 30, 40, 50, 15, 15]

# %%
arr.remove(15) #removes element from list

# %%
arr
# Out:
# [10, 20, 30, 40, 50]

# %%
arr.pop() #removes the element at last index
# Out:
# 50

# %%
arr
# Out:
# [10, 20, 30, 40]

# %%
arr = [20, 10 , 30 , 40]
arr.sort()

# %%
arr
# Out:
# [10, 20, 30, 40]

# %%
arr.reverse()

# %%
arr
# Out:
# [40, 30, 20, 10]

# %%
#boolean variables : stores : True / False
is_empty = False

#boolean checks with lists
len(arr) > 0
10 in arr
# Out:
# True

# %%
# Out:
#       Unnamed: 0  Guns_Count  Terriory_Count
# 0  Rehman Dacait          10               5
# 1         Akshit           5              10
# 2          Hamza           7               3
# 3         Aditya          10              10

# %%
# Out:
#          Ahmad  Ali  Rashed  Hamza
# apples       3    2       0      1
# oranges      0    3       7      2

# %%
#Set :: inbuilt functions: 
s = {1,2,3,4}

# %%
s.add(5)

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.remove(2) #gives error if element is not present in set

# %%
s
# Out:
# {1, 3, 4, 5}

# %%
s.discard(5) #same as remove , but give no error if element is not present in set

# %%
s
# Out:
# {1, 3, 4}

# %%
#Mathematical-Operations::
a = {1,2,3,4}
b = {3,4,5}

# %%
a.union(b) #creates a new set
# Out:
# {1, 2, 3, 4, 5}

# %%
a
# Out:
# {1, 2, 3, 4}
